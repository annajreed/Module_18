# %%
import pandas as pd

# %%
#read csv files
df1 = pd.read_csv('202205-citibike-tripdata.csv', low_memory=False)
df2 = pd.read_csv('202305-citibike-tripdata.csv', low_memory=False)
df3 = pd.read_csv('JC-202205-citibike-tripdata.csv', low_memory=False)
df4 = pd.read_csv('JC-202305-citibike-tripdata.csv', low_memory=False)

# %%
#drop null values
df1.dropna(how='all')
df2.dropna(how='all')
df3.dropna(how='all')
df4.dropna(how='all')
# Out:
#                 ride_id  rideable_type       started_at time_started  \
# 0      BC145343639B5E5B   classic_bike  5/31/2023 12:27  12:27:28 PM
# 1      A0CE41F47514FF5C   classic_bike   5/1/2023 18:12   6:12:37 PM
# 2      D588077E3D7E2AFD  electric_bike  5/28/2023 17:37   5:37:58 PM
# 3      89AC48A5584B2DB4   classic_bike  5/27/2023 21:01   9:01:37 PM
# 4      709E0B11AB4A0E6C   classic_bike  5/22/2023 12:38  12:38:54 PM
# ...                 ...            ...              ...          ...
# 95997  9549398286BB59B5    docked_bike  5/27/2023 13:24   1:24:51 PM
# 95998  AB0790683044D89E   classic_bike  5/18/2023 17:12   5:12:07 PM
# 95999  68226FA538A405CA   classic_bike   5/5/2023 18:44   6:44:57 PM
# 96000  CABAC21C0F0140A5   classic_bike  5/16/2023 11:56  11:56:11 AM
# 96001  4AABD797EF6F7BB2   classic_bike  5/30/2023 11:04  11:04:46 AM
#
#               ended_at   time_ended  \
# 0      5/31/2023 12:38  12:38:36 PM
# 1       5/1/2023 18:29   6:29:03 PM
# ...

# %%
#concat nyc data into one dataframe
nyc = [df1, df2]
nycdf = pd.concat(nyc)

# %%
#concat JC data into one dataframe
jc = [df3, df4]
jcdf = pd.concat(jc)

# %%
#jcdf.head()

# %%
# save new csv files
#jcdf.to_csv('jc-citibike.csv', index=False)
#nycdf.to_csv('nyc-citibike.csv', index=False)

# %%
# check column types
#nycdf.dtypes
jcdf.dtypes
# Out:
# ride_id                object
# rideable_type          object
# started_at             object
# time_started           object
# ended_at               object
# time_ended             object
# start_station_name     object
# start_station_id       object
# end_station_name       object
# end_station_id         object
# start_lat             float64
# start_lng             float64
# end_lat               float64
# end_lng               float64
# member_casual          object
# dtype: object

# %%
# change time_started/ended columns to datetime
nycdf['time_started'] = pd.to_datetime(nycdf['time_started'])
nycdf['time_ended'] = pd.to_datetime(nycdf['time_ended'])
jcdf['time_started'] = pd.to_datetime(jcdf['time_started'])
jcdf['time_ended'] = pd.to_datetime(jcdf['time_ended'])

# %%
# concat two files together
dflist = [jcdf, nycdf]
citibikedf = pd.concat(dflist)

# %%
# add duration column with minutes biked
citibikedf['Duration'] = ((citibikedf.time_ended) - (citibikedf.time_started))/pd.Timedelta(minutes=1)

# %%
citibikedf.head()
# Out:
#             ride_id  rideable_type       started_at        time_started  \
# 0  FC9EB68D6501F079  electric_bike  5/15/2022 14:02 2023-07-27 14:02:06
# 1  932A2D5E45ACED5B  electric_bike  5/13/2022 15:30 2023-07-27 15:30:14
# 2  8C0CD371C7A5795C  electric_bike  5/31/2022 20:41 2023-07-27 20:41:39
# 3  25BC1B079FBC71B9   classic_bike  5/29/2022 17:24 2023-07-27 17:24:23
# 4  0B0F776B55C85AB8   classic_bike  5/26/2022 16:49 2023-07-27 16:49:12
#
#           ended_at          time_ended  \
# 0  5/15/2022 14:05 2023-07-27 14:05:44
# 1  5/13/2022 15:33 2023-07-27 15:33:03
# 2  5/31/2022 22:04 2023-07-27 22:04:47
# 3  5/30/2022 18:24 2023-07-27 18:24:16
# 4  5/26/2022 16:57 2023-07-27 16:57:01
#
#                          start_station_name start_station_id  \
# 0  Hoboken Terminal - Hudson St & Hudson Pl            HB101
# 1  Hoboken Terminal - Hudson St & Hudson Pl            HB101
# 2  Hoboken Terminal - Hudson St & Hudson Pl            HB101
# ...

# %%
citibikedf.to_csv('combined_citibike.csv', index=False)
